# %% [markdown]
# <a href="https://colab.research.google.com/github/esaheki/imersao_dados_alura/blob/main/Imersao_dados_4_aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados["Valor"].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head(5)
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","", regex=False).astype(float)
# Out:
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","", regex=False).astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas.query("Valor_anuncio_float < 10000000")["Valor_anuncio_float"].plot.hist(bins = 50, log=False)

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas.describe(include="all")
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# #Desafio Aula 2
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusão
# - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %%
dados_vendas["Valor_anuncio_milhoes"] = (dados_vendas["Valor_anuncio_float"]/1000000)

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  \
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00
#
#        Valor_anuncio_milhoes
# count                9156.00
# mean                    3.05
# std                     3.94
# min                     0.01
# 25%                     0.89
# 50%                     1.80
# 75%                     3.50
# max                    65.00

# %%
sns.set()
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(15, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_milhoes", kde = False, color = "teal", lw=2, bins=65, edgecolor="white")
ax.set_title("Imóveis em São Paulo", size=16)
ax.set(xlabel='Valor do imóvel em milhões de reais', ylabel='Quantidade de imóveis à venda')
plt.xlim((-0.5, 10.5))
plt.show()

# %%
dados_vendas["Valor_metro_quadrado"] = (dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas  \
# Bairro
# Aclimação          246.164557  3.265823   3.037975  2.911392
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       299.250000  3.150000   3.850000  4.000000
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  429.853659  3.937669   4.829268  4.951220
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        173.583333  3.083333   3.250000  2.250000
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          186.166667  2.666667   2.000000  3.666667
#
#                    Valor_anuncio_float  Valor_metro_quadrado
# Bairro
# Aclimação                 1.763200e+06           7656.169465
# Alto da Boa Vista         2.391250e+06           5849.569011
# ...

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  \
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00
#
#        Valor_anuncio_milhoes  Valor_metro_quadrado
# count                9156.00               9156.00
# mean                    3.05               8004.07
# std                     3.94               5291.32
# min                     0.01                  9.33
# 25%                     0.89               4750.00
# 50%                     1.80               6500.00
# ...

# %% [markdown]
# Explorando os valores, tipos de graficos e bibliotecas

# %%
sns.jointplot(data=dados_vendas, x="Metragem", y="Valor_anuncio_float", height=10)

# %%
sns.jointplot(data=dados_vendas.query("Metragem < 10000"), x="Metragem", y="Valor_anuncio_float", height=10)

# %%
plot_data = dados_vendas.groupby(['Bairro']).agg( 
    mean_metragem = ('Metragem','mean'),
    mean_valor_metro = ('Valor_metro_quadrado','mean'),
    count = ('Bairro', 'count'))


plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=plot_data, x="mean_metragem", y="mean_valor_metro", hue="count", size="count", palette="viridis", sizes=(10, 800)
)

# %%
plot_data = dados_vendas.query("Metragem < 10000 & Valor_metro_quadrado < 80000").groupby(['Bairro']).agg( 
    mean_metragem = ('Metragem','mean'),
    mean_valor_metro = ('Valor_metro_quadrado','mean'),
    count = ('Bairro', 'count'))


plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=plot_data, x="mean_metragem", y="mean_valor_metro", hue="count", size="count", palette="viridis", sizes=(10, 800)
)

# %%
plot_data = dados_vendas.query("Metragem < 1500 & Valor_metro_quadrado < 80000").groupby(['Bairro']).agg( 
    mean_metragem = ('Metragem','mean'),
    mean_valor_metro = ('Valor_metro_quadrado','mean'),
    count = ('Bairro', 'count'))


plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=plot_data, x="mean_metragem", y="mean_valor_metro", hue="count", size="count", palette="viridis", sizes=(10, 800)
)

# %%
plot_data = dados_vendas.query("Metragem < 10000 & Valor_metro_quadrado < 80000").groupby("Bairro", as_index=False).mean().sort_values(by='Valor_metro_quadrado', ascending=False)
plt.figure(figsize=(20, 160))
ax = sns.barplot(data=plot_data, x="Valor_metro_quadrado", y="Bairro")
ax.set_title("Média do metro quadrado por bairros de São Paulo")
ax.set(xlabel='Valor do metro quadrado em reais', ylabel='Bairro')
plt.show()

# %%
plot_data = dados_vendas.query("Metragem < 10000 & Valor_metro_quadrado < 80000").groupby("Bairro", as_index=False).mean().sort_values(by='Valor_metro_quadrado', ascending=False)
divisor = pd.DataFrame({'Bairro':['...']})
plt.figure(figsize=(20, 10))
ax = sns.barplot(data=pd.concat([plot_data.head(10), divisor, plot_data.tail(10)]), x="Valor_metro_quadrado", y="Bairro")
ax.set_title("Top 10 bairros com o metro quadrado mais caros e mais baratos em São Paulo", size=16)
ax.set(xlabel='Valor do metro quadrado em reais')
plt.show()

# %% [markdown]
# Identificando percentils e outliers

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data = dados_vendas, x = "Metragem")

# %%
plt.figure(figsize=(20, 160))
sns.boxplot(data = dados_vendas.query("Metragem < 10000").sort_values("Bairro"), x = "Metragem", y="Bairro")

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data = dados_vendas, x = "Valor_anuncio_float")

# %%
plt.figure(figsize=(20, 16))
sns.boxplot(data=dados_vendas[["Quartos", "Banheiros", "Vagas"]])

# %% [markdown]
# Instalando Galeritas
# [link](https://medium.com/creditas-tech/galeritas-uma-biblioteca-para-visualiza%C3%A7%C3%A3o-de-dados-ef5ab0652268)

# %%
# !pip install galeritas
from galeritas import plot_ecdf_curve
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Valor_anuncio_float',
    figsize=(20, 6),
    plot_title='ECDF da valor de venda'
)

# %%
dados_vendas.query("Valor_anuncio_float > 30000000")
# Out:
#                        Rua             Bairro     Cidade  Metragem  Quartos  \
# 102         Rua Inglaterra      Jardim Europa  São Paulo       756        5
# 400                    NaN      Jardim Europa  São Paulo      1510        5
# 1530  Praça Nicolau Scarpa     Jardim América  São Paulo      1200        4
# 2906    Rua ESão Pauloanha      Jardim Europa  São Paulo      1400        4
# 3542                   NaN     Jardim América  São Paulo       773        4
# 6131    Rua Estados Unidos     Jardim América  São Paulo      1816        4
# 6882    Rua Estados Unidos     Jardim América  São Paulo      1200        4
# 8364                   NaN  Jardim Petrópolis  São Paulo       912        4
#
#       Banheiros  Vagas          Valor Moeda Valor_anuncio Tipo_anuncio  \
# 102           4     10  R$ 37.000.000    R$    37.000.000         None
# 400           5     20  R$ 65.000.000    R$    65.000.000         None
# ...

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Metragem',
    figsize=(20, 6),
    plot_title='ECDF da metragem'
)

# %%
dados_vendas.query("Metragem > 10000")
# Out:
#                               Rua            Bairro     Cidade  Metragem  \
# 6600       Rua Benedito Felizardo     Sítio Represa  São Paulo     37000
# 6883                          NaN  Jardim da Glória  São Paulo     35677
# 9845  Avenida George Saville Dodd    Jardim Guedala  São Paulo    750000
#
#       Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 6600        4          2      4  R$ 2.900.000    R$     2.900.000
# 6883        3          3      4  R$ 2.550.000    R$     2.550.000
# 9845        5          9      6  R$ 7.000.000    R$     7.000.000
#
#      Tipo_anuncio  Valor_anuncio_float  Valor_metro_quadrado
# 6600         None            2900000.0             78.378378
# 6883         None            2550000.0             71.474620
# 9845         None            7000000.0              9.333333

# %% [markdown]
# Filtrando provaveis outliers na coluna Metragem.

# %%
plot_ecdf_curve(
    dados_vendas.query("Metragem < 10000"),
    column_to_plot='Metragem',
    figsize=(20, 6),
    plot_title='ECDF da metragem menor que 10.000 m2'
)

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Vagas',
    figsize=(20, 6),
    plot_title='ECDF da quandidade de vagas'
)

# %%
dados_vendas.query("Vagas > 20")
# Out:
#                                      Rua          Bairro     Cidade  Metragem  \
# 627                Avenida das Magnólias   Cidade Jardim  São Paulo      1915
# 643                Avenida das Magnólias   Cidade Jardim  São Paulo      1920
# 1530                Praça Nicolau Scarpa  Jardim América  São Paulo      1200
# 1586                         Rua Araruba  Praia da Lagoa  São Paulo       600
# 1598  Rua Desembargador Paulo Passaláqua        Pacaembu  São Paulo       826
# 1621                                 NaN         Morumbi  São Paulo       419
# 1691                                 NaN         Morumbi  São Paulo       424
# 2307                                 NaN   Vila Cordeiro  São Paulo      1126
# 4969         Rua Comendador Elias Zarzur     Santo Amaro  São Paulo       500
# 5450         Rua Comendador Elias Zarzur     Santo Amaro  São Paulo       505
# 6882                  Rua Estados Unidos  Jardim América  São Paulo      1200
#
# ...

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Quartos',
    figsize=(20, 6),
    plot_title='ECDF da quandidade de quartos'
)

# %%
dados_vendas.query("Quartos > 10")
# Out:
#                             Rua                        Bairro     Cidade  \
# 1127                 Rua Bandim                       Boaçava  São Paulo
# 1726                        NaN               Jardim Paulista  São Paulo
# 3960            Rua Morro Verde                      Pacaembu  São Paulo
# 5175                        NaN              Parque São Lucas  São Paulo
# 5829   Rua Emanuel Guedes, 252   Conjunto Residencial Butantã  São Paulo
# 6628     Rua Carlos Petit, 175                   Vila Mariana  São Paulo
# 6642  Travessa Umberto Bignardi                       Paraíso  São Paulo
# 7426  Travessa Umberto Bignardi                       Paraíso  São Paulo
# 9711      Rua Otávio Passos, 0                     Vila Gomes  São Paulo
# 9747      Rua Otávio Passos, 0                     Vila Gomes  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas          Valor Moeda Valor_anuncio  \
# 1127       350       11          8     10   R$ 2.500.000    R$     2.500.000
# ...

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Banheiros',
    figsize=(20, 6),
    plot_title='ECDF da quandidade de banheiros'
)

# %%
dados_vendas.query("Banheiros > 15")
# Out:
#       Rua          Bairro     Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 2062  NaN  Jardim Guedala  São Paulo       488        4         40      4
# 2159  NaN  Jardim Guedala  São Paulo       493        4         40      4
#
#              Valor Moeda Valor_anuncio Tipo_anuncio  Valor_anuncio_float  \
# 2062  R$ 2.600.000    R$     2.600.000         None            2600000.0
# 2159  R$ 2.600.000    R$     2.600.000         None            2600000.0
#
#       Valor_metro_quadrado
# 2062           5327.868852
# 2159           5273.833671
