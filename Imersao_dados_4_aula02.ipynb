# %% [markdown]
# <a href="https://colab.research.google.com/github/esaheki/imersao_dados_alura/blob/main/Imersao_dados_4_aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                  Rua               Bairro     Cidade  \
# 5356                             NaN  Vila Nova Conceição  São Paulo
# 8086              Rua Rosalino Silva       Jardim Itapeva  São Paulo
# 6166             Rua Laerte Assunção    Jardim Paulistano  São Paulo
# 807                              NaN      Jardim Cordeiro  São Paulo
# 7798                             NaN    Brooklin Paulista  São Paulo
# 1882           Rua Cristóvão Pereira           Campo Belo  São Paulo
# 5041                             NaN  Jardim Campo Grande  São Paulo
# 3322  Avenida Doutor Cardoso de Melo         Vila Olímpia  São Paulo
# 5513                             NaN       Retiro Morumbi  São Paulo
# 2845           Rua Senador João Lira             Pacaembu  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 5356       117        3          3      2
# 8086       134        3          3      3
# 6166       400        4          6      5
# 807        587        4          7      6
# 7798       345        3          2      2
# 1882       428        5          2      3
# 5041       190        3          3      4
# 3322       205        2          3      2
# 5513       850        4          5      6
# 2845       305        4          4      3
#
#                                      Valor
# 5356  R$ 7.500\n                      /Mês
# 8086                            R$ 620.000
# 6166                          R$ 7.000.000
# 807                           R$ 3.200.000
# 7798                          R$ 2.660.000
# 1882                          R$ 2.800.000
# 5041                          R$ 1.500.000
# 3322                          R$ 2.900.000
# 5513                          R$ 7.500.000
# 2845                          R$ 2.500.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# 120         3          5      2  R$ 2.450.000
# 155         3          4      2  R$ 1.490.000
# 160         4          5      3  R$ 2.200.000
# 334         6          4     10  R$ 1.700.000
# ...       ...        ...    ...           ...
# 9645        3          5      5  R$ 1.650.000
# 9701        3          2      4  R$ 1.650.000
# 9737        3          2      4  R$ 1.650.000
# 9807        3          1      6  R$ 1.500.000
# 9852        3          3      4  R$ 1.600.000
#
# [184 rows x 8 columns]

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                   Rua                          Bairro  \
# 258             Rua Lourenço Castanho             Vila Nova Conceição
# 8678  Rua Edmundo Luiz Wagner, , 645                         Ipiranga
# 3694   Rua Professor Atílio Innocenti             Vila Nova Conceição
# 1151                    Rua Carangola                  Jardim Guedala
# 8760            Rua José Correia Lima  Jardim Felicidade (Zona Oeste)
# 2599                              NaN        Instituto de Previdência
# 3429         Rua General Mena Barreto                 Jardim Paulista
# 9038           Avenida Mahatma Gandhi                      Interlagos
# 291     Rua General Vitorino Monteiro                     Vila Romana
# 3359             Rua Lomas Valentinas                    Alto da Lapa
#
#          Cidade  Metragem  Quartos  Banheiros  Vagas         Valor
# 258   São Paulo       280        4          3      8  R$ 3.995.000
# 8678  São Paulo       133        2          2      2    R$ 719.999
# 3694  São Paulo       110        2          2      1  R$ 1.500.000
# 1151  São Paulo       609        4          6      6  R$ 4.000.000
# 8760  São Paulo        70        3          1      1    R$ 440.000
# 2599  São Paulo       245        3          4      4    R$ 990.000
# 3429  São Paulo       550        4          5      8  R$ 8.500.000
# 9038  São Paulo       455        3          4      4  R$ 3.000.000
# 291   São Paulo       450        5          5      4  R$ 2.100.000
# 3359  São Paulo       380        3          4      4  R$ 2.850.000

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados["Valor"].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head(50)
# Out:
#                                                Rua  \
# 0                            Avenida Itacira, 255
# 1                   Rua Aurelia Perez Alvarez, 42
# 2                                  Rua Alba Valdez
# 3                                              NaN
# 4                         Rua Tobias Barreto, 195
# 5                                  Rua Graham Bell
# 6                         Rua Francisco Paulo, 31
# 7                      Rua Guilherme Valente, 150
# 8                          Rua Sagrada Família, 8
# 9                                       Rua Tapaji
# 10                   Rua Vigário João Álvares, 66
# 11                                             NaN
# 12                                  Rua Tuim, 449
# 13                 Rua Antônio Pereira Mendes, 98
# 14                  Rua João Antunes Carvalho, 75
# 15                                       Rua Timbé
# 16                                 Rua João Tauler
# 17                     Rua Alice Garcia Vega, 345
# 18                           Rua Graham Bell, 332
# 19  Avenida Antônio Joaquim de Moura Andrade, 294
# 20                     Rua Marcos Fernandes, 1039
# 21                  Rua José Leão dos Santos, 606
# 22                   Rua Jaime Pinto Ferreira, 93
# 23                             Rua Aldo de Azevedo
# 24                           Rua Antônio Wey, 161
# 25               Rua João Francisco de Moura, 111
# 26                     Rua Serra de Botucatu, 993
# 27                          Rua Andrade Neves, 37
# 28                                   Rua Japeacaba
# 29                           Rua Senador Vergueiro
# 30                                Rua dos Plátanos
# 31                                             NaN
# 32                      Rua Domingos Menezes, 179
# 33                             Rua Manuel Monteiro
# 34                          Rua Serra da Sentinela
# 35                            Avenida Maria Estela
# 36              Rua Professor Ciro Formicola, 203
# 37                           Rua Elias Gannam, 53
# 38                      Rua Zacarias de Gois, 431
# 39                    Rua Gregório Paes de Almeida
# 40                           Avenida das Magnólias
# 41                                Rua Mata Machado
# 42                      Rua Alfonso de Albuquerque
# 43                 Rua Vicente Góes e Aranha, 587
# 44         Avenida Presidente Tancredo Neves, 668
# 45                     Rua Antônio Assumpção, 225
# 46                               Rua Lauro Luchesi
# 47                         Rua Artur Montenegro, 9
# 48               Avenida Dom Rodrigo Sanches, 828
# 49                       Rua Domingos de Braga, 7
#
#                             Bairro     Cidade  Metragem  Quartos  Banheiros  \
# 0                Planalto Paulista  São Paulo      1000        4          8
# 1               Jardim dos Estados  São Paulo       496        4          4
# 2                  Jardim Reimberg  São Paulo       125        4          3
# 3                   Jardim Morumbi  São Paulo       310        3          2
# 4                            Mooca  São Paulo       100        3          2
# 5                      Santo Amaro  São Paulo       440        4          4
# 6                Cidade Mãe do Céu  São Paulo       145        4          4
# 7                 Jardim Vergueiro  São Paulo       150        2          2
# 8                   Jardim Benfica  São Paulo        48        2          1
# 9                      Vila Alpina  São Paulo       114        3          3
# 10                  Vila Monumento  São Paulo       261        4          4
# 11                Jardim Luzitânia  São Paulo       436        4          3
# 12                 Vila Uberabinha  São Paulo       193        3          3
# 13                Jardim Prudência  São Paulo       251        3          5
# 14                Lauzane Paulista  São Paulo       300        4          5
# 15              Jardim Santa Maria  São Paulo       135        3          3
# 16                       Vila Nova  São Paulo       180        4          2
# 17                       Itaberaba  São Paulo       300        3          5
# 18                     Santo Amaro  São Paulo       772        7          7
# 19             Vila Nova Conceição  São Paulo       605        3          3
# 20                 Jardim da Saúde  São Paulo       110        3          2
# 21            Jardim Santo Antônio  São Paulo       250        4          4
# 22                     Vila Mazzei  São Paulo       120        2          1
# 23                   Vila Madalena  São Paulo       170        2          2
# 24                    Jardim Ivana  São Paulo       250        3          1
# 25               Vila Campo Grande  São Paulo       110        3          3
# 26               Vila Gomes Cardim  São Paulo       120        3          2
# 27                    Bela Aliança  São Paulo       502        4          6
# 28                  Vila Albertina  São Paulo       268        3          6
# 29                     Santo Amaro  São Paulo       355        4          7
# 30                   Cidade Jardim  São Paulo      1195        4          4
# 31                  Parque da Lapa  São Paulo       220        4          4
# 32                   Vila Libanesa  São Paulo       320        5          4
# 33                 Cidade Domitila  São Paulo       180        3          3
# 34                Vila Nova Savoia  São Paulo       325        4          6
# 35             Jardim Maria Estela  São Paulo       110        2          1
# 36               Parque São Rafael  São Paulo       125        2          1
# 37               Vila Bandeirantes  São Paulo       120        2          3
# 38                 Parque Colonial  São Paulo       138        3          1
# 39                   Vila Madalena  São Paulo       401        5          9
# 40                   Cidade Jardim  São Paulo       420        4          4
# 41                 Vila Califórnia  São Paulo       260        4          4
# 42              Jardim das Imbuias  São Paulo       200        3          5
# 43                 Vila Tramontano  São Paulo       463        4          6
# 44                      Vila Nancy  São Paulo       132        2          1
# 45                  Parada Inglesa  São Paulo       154        2          4
# 46  Jardim Leonor Mendes de Barros  São Paulo       300        4          4
# 47                      Jardim Iva  São Paulo       250        2          2
# 48                   Jardim Amália  São Paulo       120        2          2
# 49               Vila dos Remédios  São Paulo       110        3          3
#
#     Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0       6  R$ 7.000.000    R$     7.000.000         None
# 1       4  R$ 3.700.000    R$     3.700.000         None
# 2       2    R$ 380.000    R$       380.000         None
# 3       4    R$ 685.000    R$       685.000         None
# 4       2    R$ 540.000    R$       540.000         None
# 5       6  R$ 1.980.000    R$     1.980.000         None
# 6       2    R$ 850.000    R$       850.000         None
# 7       2    R$ 450.000    R$       450.000         None
# 8       1    R$ 199.900    R$       199.900         None
# 9       2    R$ 585.000    R$       585.000         None
# 10      3    R$ 700.000    R$       700.000         None
# 11      3     R$ 15.000    R$        15.000         None
# 12      2  R$ 2.500.000    R$     2.500.000         None
# 13      4  R$ 1.700.000    R$     1.700.000         None
# 14      4  R$ 1.150.000    R$     1.150.000         None
# 15      2    R$ 550.000    R$       550.000         None
# 16      4    R$ 420.000    R$       420.000         None
# 17      4  R$ 2.232.000    R$     2.232.000         None
# 18      6  R$ 2.700.000    R$     2.700.000         None
# 19      4  R$ 4.190.000    R$     4.190.000         None
# 20      5    R$ 860.000    R$       860.000         None
# 21      4    R$ 650.000    R$       650.000         None
# 22      1    R$ 490.000    R$       490.000         None
# 23      1  R$ 1.485.000    R$     1.485.000         None
# 24      5    R$ 650.000    R$       650.000         None
# 25      2    R$ 550.000    R$       550.000         None
# 26      2  R$ 1.100.000    R$     1.100.000         None
# 27      4  R$ 2.985.000    R$     2.985.000         None
# 28      4  R$ 1.700.000    R$     1.700.000         None
# 29      4  R$ 3.100.000    R$     3.100.000         None
# 30      6  R$ 8.700.000    R$     8.700.000         None
# 31      3    R$ 849.000    R$       849.000         None
# 32      6    R$ 890.000    R$       890.000         None
# 33      4    R$ 550.000    R$       550.000         None
# 34      3  R$ 1.650.000    R$     1.650.000         None
# 35      1    R$ 445.000    R$       445.000         None
# 36      2    R$ 425.000    R$       425.000         None
# 37      2    R$ 500.000    R$       500.000         None
# 38      3  R$ 1.060.000    R$     1.060.000         None
# 39      4  R$ 3.890.000    R$     3.890.000         None
# 40      4  R$ 2.200.000    R$     2.200.000         None
# 41      4  R$ 1.250.000    R$     1.250.000         None
# 42      3  R$ 1.250.000    R$     1.250.000         None
# 43      6  R$ 2.200.000    R$     2.200.000         None
# 44      1    R$ 390.000    R$       390.000         None
# 45      4    R$ 650.000    R$       650.000         None
# 46      3  R$ 1.600.000    R$     1.600.000         None
# 47      2    R$ 370.000    R$       370.000         None
# 48      1    R$ 130.000    R$       130.000         None
# 49      2    R$ 545.000    R$       545.000         None

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 10002         None
# 10003         None
# 10004         None
# 10005         None
# 10007         None
#
# [9156 rows x 11 columns]

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","", regex=False).astype(float)
# Out:
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","", regex=False).astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas.query("Valor_anuncio_float < 10000000")["Valor_anuncio_float"].plot.hist(bins = 50, log=False)

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas.describe(include="all")
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
#         Banheiros   Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# count     9156.00 9156.00          9156  9156          9156            0
# unique        NaN     NaN           939     1           939            0
# top           NaN     NaN  R$ 2.500.000    R$     2.500.000          NaN
# freq          NaN     NaN           182  9156           182          NaN
# mean         3.80    3.96           NaN   NaN           NaN          NaN
# std          1.97    2.60           NaN   NaN           NaN          NaN
# min          1.00    1.00           NaN   NaN           NaN          NaN
# 25%          2.00    2.00           NaN   NaN           NaN          NaN
# 50%          4.00    4.00           NaN   NaN           NaN          NaN
# 75%          5.00    5.00           NaN   NaN           NaN          NaN
# max         40.00   50.00           NaN   NaN           NaN          NaN
#
#         Valor_anuncio_float
# count               9156.00
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean             3052202.96
# std              3944208.19
# min                13000.00
# 25%               890000.00
# 50%              1800000.00
# 75%              3500000.00
# max             65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# #Desafio Aula 2
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusão
# - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %%
dados_vendas["Valor_anuncio_milhoes"] = (dados_vendas["Valor_anuncio_float"]/1000000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  \
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00
#
#        Valor_anuncio_milhoes
# count                9156.00
# mean                    3.05
# std                     3.94
# min                     0.01
# 25%                     0.89
# 50%                     1.80
# 75%                     3.50
# max                    65.00

# %%
sns.set()
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(15, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_milhoes", kde = False, color = "teal", lw=2, bins=65, edgecolor="white")
ax.set_title("Imóveis em São Paulo")
ax.set(xlabel='Valor do imóvel em milhões de reais', ylabel='Quantidade de imóveis à venda')
plt.xlim((-0.5, 10.5))
plt.show()

# %%
dados_vendas["Valor_metro_quadrado"] = (dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"])

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor_anuncio_milhoes  Valor_metro_quadrado
# Bairro
# Aclimação                           1.76               7656.17
# Alto da Boa Vista                   2.39               5849.57
# Alto da Lapa                        2.08               7606.73
# Alto da Mooca                       1.18               5691.74
# Alto de Pinheiros                   4.78              11269.98
# ...                                  ...                   ...
# Vila Água Funda                     0.65               4467.13
# Água Branca                         1.23               7269.11
# Água Fria                           0.93               5841.10
# Água Funda                          0.55               3876.86
# Água Rasa                           0.72               4509.61
#
# [697 rows x 7 columns]

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  \
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00
#
#        Valor_anuncio_milhoes  Valor_metro_quadrado
# count                9156.00               9156.00
# mean                    3.05               8004.07
# std                     3.94               5291.32
# min                     0.01                  9.33
# 25%                     0.89               4750.00
# 50%                     1.80               6500.00
# 75%                     3.50               9453.78
# max                    65.00              80000.00

# %% [markdown]
# Explorando os valores, tipos de graficos e bibliotecas

# %%
sns.jointplot(data=dados_vendas, x="Metragem", y="Valor_anuncio_float", height=10)

# %%
sns.jointplot(data=dados_vendas.query("Metragem < 200000"), x="Metragem", y="Valor_anuncio_float", height=10)

# %%
plot_data = dados_vendas.query("Metragem < 10000 & Valor_metro_quadrado < 80000").groupby(['Bairro']).agg( 
    mean_metragem = ('Metragem','mean'),
    mean_valor_metro = ('Valor_metro_quadrado','mean'),
    count = ('Bairro', 'count'))


plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=plot_data, x="mean_metragem", y="mean_valor_metro", hue="count", size="count", palette="viridis", sizes=(10, 200)
)

# %%
plt.figure(figsize=(20, 160))
ax = sns.barplot(data=dados_vendas.query("Metragem < 10000 & Valor_metro_quadrado < 80000").groupby("Bairro", as_index=False).mean().sort_values(by='Valor_metro_quadrado', ascending=False),
            x="Valor_metro_quadrado",
            y="Bairro")
ax.set_title("Média do metro quadrado por bairros de São Paulo")
ax.set(xlabel='Valor do metro quadrado em reais', ylabel='Bairro')
plt.show()

# %% [markdown]
# Identificando percentils e outliers

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data = dados_vendas, x = "Metragem")

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data = dados_vendas, x = "Valor_anuncio_float")

# %% [markdown]
# Instalando Galeritas
# [link](https://medium.com/creditas-tech/galeritas-uma-biblioteca-para-visualiza%C3%A7%C3%A3o-de-dados-ef5ab0652268)

# %%
# !pip install galeritas
from galeritas import plot_ecdf_curve
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: galeritas in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from galeritas) (1.4.1)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from galeritas) (0.11.2)
# Requirement already satisfied: scikit-learn>=0.20.4 in /usr/local/lib/python3.7/dist-packages (from galeritas) (1.0.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from galeritas) (1.3.5)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.7/dist-packages (from galeritas) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from galeritas) (1.21.6)
# Requirement already satisfied: pytest-mpl>=0.12.0 in /usr/local/lib/python3.7/dist-packages (from galeritas) (0.15.1)
# Requirement already satisfied: pytest>=6.1.2 in /usr/local/lib/python3.7/dist-packages (from galeritas) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->galeritas) (1.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.3->galeritas) (4.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.3->galeritas) (2022.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.1.2->galeritas) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.1.2->galeritas) (21.4.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest>=6.1.2->galeritas) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.1.2->galeritas) (2.0.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.1.2->galeritas) (1.11.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.1.2->galeritas) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest>=6.1.2->galeritas) (3.8.0)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.7/dist-packages (from pytest-mpl>=0.12.0->galeritas) (2.11.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from pytest-mpl>=0.12.0->galeritas) (5.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->galeritas) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.4->galeritas) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.4->galeritas) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2->pytest-mpl>=0.12.0->galeritas) (2.0.1)

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Valor_anuncio_float',
    figsize=(20, 6),
    plot_title='ECDF da valor de venda'
)

# %%
plot_ecdf_curve(
    dados_vendas,
    column_to_plot='Metragem',
    figsize=(20, 6),
    plot_title='ECDF da metragem'
)

# %%
plot_ecdf_curve(
    dados_vendas.query("Metragem < 10000"),
    column_to_plot='Metragem',
    figsize=(20, 6),
    plot_title='ECDF da metragem menor que 10.000 m2'
)
